# %% [markdown]
# # **Import needed libraries**

# %%
# import system libs
import os
import itertools

# import data handling tools
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from keras.applications import VGG16

# ignore the warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Loading the dataset**
#
# > Read the training dataset into the dataframe

# %%
import os
import pandas as pd

def loading_the_data(data_dir):
    # Generate data paths with labels
    filepaths = []
    labels = []

    # Get folder names
    folds = os.listdir(data_dir)

    for fold in folds:
        foldpath = os.path.join(data_dir, fold)
        filelist = os.listdir(foldpath)
        for file in filelist:
            fpath = os.path.join(foldpath, file)
            
            filepaths.append(fpath)
            labels.append(fold)

    # Concatenate data paths with labels into one DataFrame
    Fseries = pd.Series(filepaths, name='filepaths')
    Lseries = pd.Series(labels, name='labels')

    df = pd.concat([Fseries, Lseries], axis=1)
    
    return df
    
def change_label_names(df, column_name):
    index = {'n0': 'mantled_howler', 'n1': 'patas_monkey', 'n2': 'bald_uakari', 'n3': 'japanese_macaque', 
        'n4': 'pygmy_marmoset', 'n5': 'white_headed_capuchin', 'n6': 'silvery_marmoset', 
        'n7': 'common_squirrel_monkey', 'n8': 'black_headed_night_monkey', 'n9': 'nilgiri_langur'}

    df[column_name] = df[column_name].replace(index)

# Define data directory
data_dir = 'archive/training/training'  # Update with your data directory

# Load the data
train_df = loading_the_data(data_dir)

# Change label names
change_label_names(train_df, 'labels')

# %%
change_label_names(train_df, 'labels')

# %%
train_df
# Out:
#                                    filepaths          labels
# 0     archive/training/training\n0\n0018.jpg  mantled_howler
# 1     archive/training/training\n0\n0019.jpg  mantled_howler
# 2     archive/training/training\n0\n0020.jpg  mantled_howler
# 3     archive/training/training\n0\n0021.jpg  mantled_howler
# 4     archive/training/training\n0\n0022.jpg  mantled_howler
# ...                                      ...             ...
# 1093  archive/training/training\n9\n9161.jpg  nilgiri_langur
# 1094  archive/training/training\n9\n9162.jpg  nilgiri_langur
# 1095  archive/training/training\n9\n9163.jpg  nilgiri_langur
# 1096   archive/training/training\n9\n917.jpg  nilgiri_langur
# 1097   archive/training/training\n9\n919.jpg  nilgiri_langur
#
# [1098 rows x 2 columns]

# %% [markdown]
# > read the testing dataset into the dataframe

# %%
# Define data directory for validation data
data_dir_validation = 'archive/validation/validation'  # Update with your validation data directory

# Load the validation data
ts_df = loading_the_data(data_dir_validation)

# %%
change_label_names(ts_df, 'labels')

# %%
ts_df
# Out:
#                                       filepaths          labels
# 0     archive/validation/validation\n0\n000.jpg  mantled_howler
# 1     archive/validation/validation\n0\n001.jpg  mantled_howler
# 2    archive/validation/validation\n0\n0010.jpg  mantled_howler
# 3    archive/validation/validation\n0\n0011.jpg  mantled_howler
# 4    archive/validation/validation\n0\n0012.jpg  mantled_howler
# ..                                          ...             ...
# 267   archive/validation/validation\n9\n912.jpg  nilgiri_langur
# 268   archive/validation/validation\n9\n913.jpg  nilgiri_langur
# 269   archive/validation/validation\n9\n914.jpg  nilgiri_langur
# 270   archive/validation/validation\n9\n916.jpg  nilgiri_langur
# 271   archive/validation/validation\n9\n918.jpg  nilgiri_langur
#
# [272 rows x 2 columns]

# %% [markdown]
# # **Data preprocessing**
# first we will check if the training data is balanced or not

# %%
import matplotlib.pyplot as plt

# Calculate data balance
data_balance = train_df.labels.value_counts()

# Define a custom function for autopct
def custom_autopct(pct):
    total = sum(data_balance)
    val = int(round(pct*total/100.0))
    return "{:.1f}%\n({:d})".format(pct, val)

# Define colors
colors = ["#2092E6", "#6D8CE6", "#20D0E6", "#A579EB", "#E684B0", "#EBB684", "#84EB8E", "#84B0E6", "#E68484", "#84E6E6"]

# Create a pie chart for data balance
plt.figure(figsize=(8, 8))  # Set the size of the figure
plt.pie(data_balance, labels=data_balance.index, autopct=custom_autopct, colors=colors, startangle=140)  # Adjust start angle for better visualization
plt.title("Distribution of Monkey Species in Training Data", fontsize=16, pad=20)  # Add a title with larger font size and padding
plt.axis("equal")  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# It is balanced but very small, so we will augment this training data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate data balance
data_balance = train_df.labels.value_counts()

# Create bar plot for data balance
plt.figure(figsize=(12, 8))
sns.barplot(x=data_balance.index, y=data_balance.values, palette="viridis")
plt.title("Training Data Balance", fontsize=18)
plt.xlabel("Monkey Species", fontsize=14)
plt.ylabel("Number of Images", fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
for index, value in enumerate(data_balance.values):
    plt.text(index, value + 10, str(value), ha='center', va='bottom', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# valid and test dataframe
valid_df, test_df = train_test_split(ts_df, train_size = 0.5, shuffle = True, random_state = 42)

# %% [markdown]
# **Create image data generator**
#
# in this step we will augment training data and converting the whoole data to numpy arrays

# %%
# crobed image size
batch_size = 8
img_size = (224, 224)

tr_gen = ImageDataGenerator(rescale=1. / 255,
                           rotation_range=20,       # Random rotations from 0 to 20 degrees
                           width_shift_range=0.2,   # Random horizontal shifts
                           height_shift_range=0.2,  # Random vertical shifts
                           zoom_range=0.3,          # Random zoom
                           horizontal_flip=True,    # Random horizontal flips
                           fill_mode='nearest'      # Strategy for filling in newly created pixels
                           )
ts_gen = ImageDataGenerator(rescale=1. / 255)

train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= batch_size)
# Out:
# Found 1098 validated image filenames belonging to 10 classes.
# Found 136 validated image filenames belonging to 10 classes.
# Found 136 validated image filenames belonging to 10 classes.

# %% [markdown]
# **Display sample from train data**

# %%
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

# ploting the patch size samples
plt.figure(figsize= (20, 20))

for i in range(batch_size):
    plt.subplot(4, 4, i + 1)
    image = images[i]
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'black', fontsize= 16)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Model Structure**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras import regularizers

# Define input shape
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

# Get the number of classes
class_counts = len(train_gen.class_indices)

# Get the pre-trained model (VGG16)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=img_shape, pooling='max')

# Freeze convolutional blocks
for layer in base_model.layers[:15]:
    layer.trainable = False

# Fine-tune VGG16 (Adding custom layers on top)
x = base_model.output
x = Flatten()(x)
x = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)  # Regularization
x = BatchNormalization()(x)  # Batch Normalization
x = Dropout(0.5)(x)  # Increased Dropout Rate
x = Dense(256, activation=LeakyReLU(alpha=0.1))(x)  # Different Activation Functions
x = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)  # Regularization
x = BatchNormalization()(x)  # Batch Normalization
x = Dense(64, activation='relu')(x)  # Additional Dense Layer
x = Dense(32, activation='relu')(x)  # Additional Dense Layer
predictions = Dense(class_counts, activation='softmax')(x)

# Create the model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_max_pooling2d_2 (Glo  (None, 512)              0
#  balMaxPooling2D)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 15,154,794
# Trainable params: 7,518,250
# Non-trainable params: 7,636,544
# _________________________________________________________________

# %% [markdown]
# **Train the model**

# %%
epochs = 100  # number of all epochs in training
batch_size = 8   # number of batches

history = model.fit(train_gen, epochs= epochs, verbose= 1,batch_size = batch_size, validation_data= valid_gen, shuffle= False)
# Out:
# Epoch 1/100
# 138/138 [==============================] - 31s 224ms/step - loss: 7.7343 - accuracy: 0.2905 - val_loss: 8.0593 - val_accuracy: 0.1912
# Epoch 2/100
# 138/138 [==============================] - 31s 227ms/step - loss: 7.2953 - accuracy: 0.3843 - val_loss: 7.6158 - val_accuracy: 0.2647
# Epoch 3/100
# 138/138 [==============================] - 31s 225ms/step - loss: 6.9234 - accuracy: 0.4727 - val_loss: 6.7360 - val_accuracy: 0.4485
# Epoch 4/100
# 138/138 [==============================] - 32s 230ms/step - loss: 6.6454 - accuracy: 0.4863 - val_loss: 6.4212 - val_accuracy: 0.5221
# Epoch 5/100
# 138/138 [==============================] - 33s 236ms/step - loss: 6.3375 - accuracy: 0.5410 - val_loss: 6.0666 - val_accuracy: 0.6103
# Epoch 6/100
# 138/138 [==============================] - 33s 237ms/step - loss: 6.1528 - accuracy: 0.5428 - val_loss: 6.1997 - val_accuracy: 0.4632
# Epoch 7/100
# 138/138 [==============================] - 31s 228ms/step - loss: 5.8362 - accuracy: 0.6047 - val_loss: 5.6368 - val_accuracy: 0.6471
# Epoch 8/100
# 138/138 [==============================] - 31s 226ms/step - loss: 5.5422 - accuracy: 0.6612 - val_loss: 5.6837 - val_accuracy: 0.5294
# Epoch 9/100
# 138/138 [==============================] - 31s 228ms/step - loss: 5.2295 - accuracy: 0.7268 - val_loss: 5.1460 - val_accuracy: 0.7206
# Epoch 10/100
# 138/138 [==============================] - 32s 230ms/step - loss: 5.0264 - accuracy: 0.7295 - val_loss: 5.5483 - val_accuracy: 0.4926
# Epoch 11/100
# 138/138 [==============================] - 31s 227ms/step - loss: 5.0180 - accuracy: 0.6812 - val_loss: 5.0130 - val_accuracy: 0.6250
# Epoch 12/100
# 138/138 [==============================] - 32s 231ms/step - loss: 4.8121 - accuracy: 0.7013 - val_loss: 4.4171 - val_accuracy: 0.8529
# Epoch 13/100
# 138/138 [==============================] - 31s 227ms/step - loss: 4.5217 - accuracy: 0.7596 - val_loss: 4.3087 - val_accuracy: 0.8088
# Epoch 14/100
# 138/138 [==============================] - 32s 227ms/step - loss: 4.4159 - accuracy: 0.7587 - val_loss: 5.7084 - val_accuracy: 0.5294
# Epoch 15/100
# 138/138 [==============================] - 31s 227ms/step - loss: 4.1996 - accuracy: 0.7805 - val_loss: 4.1566 - val_accuracy: 0.7794
# Epoch 16/100
# 138/138 [==============================] - 32s 227ms/step - loss: 4.0005 - accuracy: 0.8142 - val_loss: 3.8396 - val_accuracy: 0.8676
# Epoch 17/100
# 138/138 [==============================] - 33s 236ms/step - loss: 3.9145 - accuracy: 0.8124 - val_loss: 3.7196 - val_accuracy: 0.8897
# Epoch 18/100
# 138/138 [==============================] - 33s 237ms/step - loss: 3.7789 - accuracy: 0.8069 - val_loss: 3.7377 - val_accuracy: 0.8309
# Epoch 19/100
# 138/138 [==============================] - 33s 238ms/step - loss: 3.6819 - accuracy: 0.8024 - val_loss: 3.7288 - val_accuracy: 0.7574
# Epoch 20/100
# 138/138 [==============================] - 33s 238ms/step - loss: 3.5076 - accuracy: 0.8215 - val_loss: 3.2723 - val_accuracy: 0.9118
# Epoch 21/100
# 138/138 [==============================] - 33s 237ms/step - loss: 3.3413 - accuracy: 0.8443 - val_loss: 3.3726 - val_accuracy: 0.8162
# Epoch 22/100
# 138/138 [==============================] - 33s 241ms/step - loss: 3.3216 - accuracy: 0.8233 - val_loss: 3.0546 - val_accuracy: 0.8897
# Epoch 23/100
# 138/138 [==============================] - 33s 236ms/step - loss: 3.1805 - accuracy: 0.8315 - val_loss: 2.9738 - val_accuracy: 0.8897
# Epoch 24/100
# 138/138 [==============================] - 31s 227ms/step - loss: 3.0913 - accuracy: 0.8506 - val_loss: 2.9712 - val_accuracy: 0.8824
# Epoch 25/100
# 138/138 [==============================] - 32s 229ms/step - loss: 2.9531 - accuracy: 0.8689 - val_loss: 2.9185 - val_accuracy: 0.8676
# Epoch 26/100
# 138/138 [==============================] - 32s 234ms/step - loss: 2.9040 - accuracy: 0.8406 - val_loss: 2.6016 - val_accuracy: 0.9485
# Epoch 27/100
# 138/138 [==============================] - 32s 228ms/step - loss: 2.7749 - accuracy: 0.8725 - val_loss: 2.6615 - val_accuracy: 0.9044
# Epoch 28/100
# 138/138 [==============================] - 31s 227ms/step - loss: 2.6645 - accuracy: 0.8780 - val_loss: 2.7755 - val_accuracy: 0.8676
# Epoch 29/100
# 138/138 [==============================] - 31s 228ms/step - loss: 2.5779 - accuracy: 0.8689 - val_loss: 2.4512 - val_accuracy: 0.9118
# Epoch 30/100
# 138/138 [==============================] - 31s 226ms/step - loss: 2.5338 - accuracy: 0.8716 - val_loss: 2.5352 - val_accuracy: 0.8603
# Epoch 31/100
# 138/138 [==============================] - 31s 227ms/step - loss: 2.4048 - accuracy: 0.8971 - val_loss: 2.3697 - val_accuracy: 0.8750
# Epoch 32/100
# 138/138 [==============================] - 31s 226ms/step - loss: 2.3202 - accuracy: 0.8916 - val_loss: 2.2472 - val_accuracy: 0.9044
# Epoch 33/100
# 138/138 [==============================] - 31s 228ms/step - loss: 2.2545 - accuracy: 0.8971 - val_loss: 2.2922 - val_accuracy: 0.8676
# Epoch 34/100
# 138/138 [==============================] - 31s 227ms/step - loss: 2.2067 - accuracy: 0.8898 - val_loss: 2.0988 - val_accuracy: 0.9338
# Epoch 35/100
# 138/138 [==============================] - 31s 227ms/step - loss: 2.1266 - accuracy: 0.9044 - val_loss: 2.0257 - val_accuracy: 0.9118
# Epoch 36/100
# 138/138 [==============================] - 31s 226ms/step - loss: 2.0351 - accuracy: 0.9044 - val_loss: 3.0899 - val_accuracy: 0.6176
# Epoch 37/100
# 138/138 [==============================] - 32s 230ms/step - loss: 1.9732 - accuracy: 0.9162 - val_loss: 1.8840 - val_accuracy: 0.9191
# Epoch 38/100
# 138/138 [==============================] - 31s 225ms/step - loss: 1.9592 - accuracy: 0.8971 - val_loss: 2.4240 - val_accuracy: 0.7279
# Epoch 39/100
# 138/138 [==============================] - 31s 225ms/step - loss: 1.9655 - accuracy: 0.8889 - val_loss: 1.7449 - val_accuracy: 0.9412
# Epoch 40/100
# 138/138 [==============================] - 31s 224ms/step - loss: 1.9048 - accuracy: 0.8834 - val_loss: 1.8250 - val_accuracy: 0.9044
# Epoch 41/100
# 138/138 [==============================] - 32s 229ms/step - loss: 1.8466 - accuracy: 0.8889 - val_loss: 1.6268 - val_accuracy: 0.9485
# Epoch 42/100
# 138/138 [==============================] - 31s 225ms/step - loss: 1.6857 - accuracy: 0.9271 - val_loss: 1.6517 - val_accuracy: 0.9559
# Epoch 43/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.6662 - accuracy: 0.9144 - val_loss: 1.5894 - val_accuracy: 0.9338
# Epoch 44/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.5545 - accuracy: 0.9481 - val_loss: 1.6643 - val_accuracy: 0.9191
# Epoch 45/100
# 138/138 [==============================] - 32s 232ms/step - loss: 1.5663 - accuracy: 0.9317 - val_loss: 1.6429 - val_accuracy: 0.9191
# Epoch 46/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.7032 - accuracy: 0.8789 - val_loss: 1.6447 - val_accuracy: 0.8897
# Epoch 47/100
# 138/138 [==============================] - 31s 228ms/step - loss: 1.4843 - accuracy: 0.9208 - val_loss: 1.3484 - val_accuracy: 0.9706
# Epoch 48/100
# 138/138 [==============================] - 31s 226ms/step - loss: 1.5819 - accuracy: 0.8780 - val_loss: 1.5397 - val_accuracy: 0.9118
# Epoch 49/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.4494 - accuracy: 0.9135 - val_loss: 1.3228 - val_accuracy: 0.9412
# Epoch 50/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.4181 - accuracy: 0.9080 - val_loss: 1.7600 - val_accuracy: 0.8382
# Epoch 51/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.3768 - accuracy: 0.9171 - val_loss: 1.8596 - val_accuracy: 0.7279
# Epoch 52/100
# 138/138 [==============================] - 31s 226ms/step - loss: 1.3179 - accuracy: 0.9253 - val_loss: 1.3283 - val_accuracy: 0.9338
# Epoch 53/100
# 138/138 [==============================] - 31s 228ms/step - loss: 1.2248 - accuracy: 0.9481 - val_loss: 1.2315 - val_accuracy: 0.9338
# Epoch 54/100
# 138/138 [==============================] - 32s 230ms/step - loss: 1.2162 - accuracy: 0.9408 - val_loss: 1.3011 - val_accuracy: 0.9265
# Epoch 55/100
# 138/138 [==============================] - 33s 238ms/step - loss: 1.2451 - accuracy: 0.9244 - val_loss: 1.2298 - val_accuracy: 0.9118
# Epoch 56/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.1892 - accuracy: 0.9262 - val_loss: 1.0831 - val_accuracy: 0.9706
# Epoch 57/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.1558 - accuracy: 0.9299 - val_loss: 1.2785 - val_accuracy: 0.8971
# Epoch 58/100
# 138/138 [==============================] - 31s 228ms/step - loss: 1.0701 - accuracy: 0.9508 - val_loss: 1.0924 - val_accuracy: 0.9338
# Epoch 59/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.0521 - accuracy: 0.9572 - val_loss: 1.0910 - val_accuracy: 0.9338
# Epoch 60/100
# 138/138 [==============================] - 31s 226ms/step - loss: 1.0220 - accuracy: 0.9490 - val_loss: 1.0927 - val_accuracy: 0.9632
# Epoch 61/100
# 138/138 [==============================] - 32s 229ms/step - loss: 1.0406 - accuracy: 0.9344 - val_loss: 1.0603 - val_accuracy: 0.9338
# Epoch 62/100
# 138/138 [==============================] - 31s 227ms/step - loss: 1.0081 - accuracy: 0.9426 - val_loss: 1.2687 - val_accuracy: 0.8235
# Epoch 63/100
# 138/138 [==============================] - 31s 226ms/step - loss: 0.9436 - accuracy: 0.9526 - val_loss: 1.1034 - val_accuracy: 0.9118
# Epoch 64/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.9222 - accuracy: 0.9572 - val_loss: 0.9883 - val_accuracy: 0.9265
# Epoch 65/100
# 138/138 [==============================] - 32s 233ms/step - loss: 0.9102 - accuracy: 0.9490 - val_loss: 0.9235 - val_accuracy: 0.9191
# Epoch 66/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.9180 - accuracy: 0.9463 - val_loss: 0.9132 - val_accuracy: 0.9338
# Epoch 67/100
# 138/138 [==============================] - 31s 223ms/step - loss: 0.9013 - accuracy: 0.9417 - val_loss: 1.0032 - val_accuracy: 0.9044
# Epoch 68/100
# 138/138 [==============================] - 31s 226ms/step - loss: 0.9821 - accuracy: 0.8998 - val_loss: 0.9315 - val_accuracy: 0.9265
# Epoch 69/100
# 138/138 [==============================] - 32s 232ms/step - loss: 1.0271 - accuracy: 0.8825 - val_loss: 0.9269 - val_accuracy: 0.8971
# Epoch 70/100
# 138/138 [==============================] - 32s 228ms/step - loss: 0.9004 - accuracy: 0.9253 - val_loss: 1.2220 - val_accuracy: 0.8015
# Epoch 71/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.8461 - accuracy: 0.9399 - val_loss: 0.8298 - val_accuracy: 0.9338
# Epoch 72/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.8065 - accuracy: 0.9444 - val_loss: 0.8384 - val_accuracy: 0.9338
# Epoch 73/100
# 138/138 [==============================] - 32s 232ms/step - loss: 0.8783 - accuracy: 0.9208 - val_loss: 0.8337 - val_accuracy: 0.9338
# Epoch 74/100
# 138/138 [==============================] - 31s 224ms/step - loss: 0.7869 - accuracy: 0.9472 - val_loss: 0.8151 - val_accuracy: 0.9338
# Epoch 75/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.7166 - accuracy: 0.9572 - val_loss: 0.7641 - val_accuracy: 0.9412
# Epoch 76/100
# 138/138 [==============================] - 31s 227ms/step - loss: 0.7140 - accuracy: 0.9554 - val_loss: 0.7210 - val_accuracy: 0.9338
# Epoch 77/100
# 138/138 [==============================] - 32s 230ms/step - loss: 0.6858 - accuracy: 0.9617 - val_loss: 0.6531 - val_accuracy: 0.9559
# Epoch 78/100
# 138/138 [==============================] - 31s 224ms/step - loss: 0.6835 - accuracy: 0.9545 - val_loss: 0.7053 - val_accuracy: 0.9559
# Epoch 79/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.6510 - accuracy: 0.9608 - val_loss: 0.6888 - val_accuracy: 0.9485
# Epoch 80/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.6486 - accuracy: 0.9608 - val_loss: 0.7028 - val_accuracy: 0.9191
# Epoch 81/100
# 138/138 [==============================] - 32s 230ms/step - loss: 0.6680 - accuracy: 0.9463 - val_loss: 0.6085 - val_accuracy: 0.9632
# Epoch 82/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.6165 - accuracy: 0.9554 - val_loss: 0.6339 - val_accuracy: 0.9485
# Epoch 83/100
# 138/138 [==============================] - 32s 232ms/step - loss: 0.5772 - accuracy: 0.9709 - val_loss: 0.6173 - val_accuracy: 0.9632
# Epoch 84/100
# 138/138 [==============================] - 32s 228ms/step - loss: 0.5703 - accuracy: 0.9672 - val_loss: 0.6064 - val_accuracy: 0.9338
# Epoch 85/100
# 138/138 [==============================] - 32s 233ms/step - loss: 0.5564 - accuracy: 0.9727 - val_loss: 0.6032 - val_accuracy: 0.9412
# Epoch 86/100
# 138/138 [==============================] - 31s 227ms/step - loss: 0.5607 - accuracy: 0.9627 - val_loss: 0.7160 - val_accuracy: 0.9265
# Epoch 87/100
# 138/138 [==============================] - 31s 228ms/step - loss: 0.5112 - accuracy: 0.9791 - val_loss: 0.5469 - val_accuracy: 0.9706
# Epoch 88/100
# 138/138 [==============================] - 31s 226ms/step - loss: 0.5051 - accuracy: 0.9736 - val_loss: 0.5990 - val_accuracy: 0.9338
# Epoch 89/100
# 138/138 [==============================] - 32s 232ms/step - loss: 0.5466 - accuracy: 0.9536 - val_loss: 0.6645 - val_accuracy: 0.9338
# Epoch 90/100
# 138/138 [==============================] - 31s 227ms/step - loss: 0.5207 - accuracy: 0.9617 - val_loss: 0.5758 - val_accuracy: 0.9265
# Epoch 91/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.5026 - accuracy: 0.9690 - val_loss: 0.6178 - val_accuracy: 0.9191
# Epoch 92/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.5011 - accuracy: 0.9599 - val_loss: 0.5827 - val_accuracy: 0.9412
# Epoch 93/100
# 138/138 [==============================] - 31s 227ms/step - loss: 0.4984 - accuracy: 0.9627 - val_loss: 0.5280 - val_accuracy: 0.9191
# Epoch 94/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.4843 - accuracy: 0.9599 - val_loss: 0.5105 - val_accuracy: 0.9559
# Epoch 95/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.5234 - accuracy: 0.9472 - val_loss: 0.4857 - val_accuracy: 0.9485
# Epoch 96/100
# 138/138 [==============================] - 31s 223ms/step - loss: 0.4540 - accuracy: 0.9681 - val_loss: 0.5146 - val_accuracy: 0.9559
# Epoch 97/100
# 138/138 [==============================] - 31s 228ms/step - loss: 0.4411 - accuracy: 0.9754 - val_loss: 0.5377 - val_accuracy: 0.9485
# Epoch 98/100
# 138/138 [==============================] - 31s 226ms/step - loss: 0.4339 - accuracy: 0.9690 - val_loss: 0.6053 - val_accuracy: 0.9118
# Epoch 99/100
# 138/138 [==============================] - 31s 225ms/step - loss: 0.4030 - accuracy: 0.9699 - val_loss: 0.4472 - val_accuracy: 0.9485
# Epoch 100/100
# 138/138 [==============================] - 31s 226ms/step - loss: 0.4266 - accuracy: 0.9699 - val_loss: 0.4815 - val_accuracy: 0.9338

# %% [markdown]
# **Display model performance**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

Epochs = range(1, len(tr_acc) + 1)

# Plot training history
plt.figure(figsize=(18, 8))
plt.style.use('ggplot')

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label='Training Loss')
plt.plot(Epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Annotate the minimum validation loss
min_val_loss = min(val_loss)
min_val_loss_epoch = val_loss.index(min_val_loss) + 1
plt.annotate(f'Min Val Loss: {min_val_loss:.4f}', xy=(min_val_loss_epoch, min_val_loss),
             xytext=(min_val_loss_epoch, min_val_loss + 0.5),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label='Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Annotate the maximum validation accuracy
max_val_acc = max(val_acc)
max_val_acc_epoch = val_acc.index(max_val_acc) + 1
plt.annotate(f'Max Val Acc: {max_val_acc:.4f}', xy=(max_val_acc_epoch, max_val_acc),
             xytext=(max_val_acc_epoch, max_val_acc - 0.1),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Evaluate the model**

# %%
import matplotlib.pyplot as plt

# Get evaluation scores
train_score = model.evaluate(train_gen, verbose=1)
valid_score = model.evaluate(valid_gen, verbose=1)
test_score = model.evaluate(test_gen, verbose=1)

# Define labels and scores
labels = ['Train', 'Validation', 'Test']
loss_scores = [train_score[0], valid_score[0], test_score[0]]
accuracy_scores = [train_score[1], valid_score[1], test_score[1]]

# Plot loss scores
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.bar(labels, loss_scores, color=['blue', 'orange', 'green'])
plt.title('Loss Scores')
plt.ylabel('Loss')
for i in range(len(labels)):
    plt.text(i, loss_scores[i] + 0.01, f'{loss_scores[i]:.4f}', ha='center')
plt.tight_layout()

# Plot accuracy scores
plt.subplot(1, 2, 2)
plt.bar(labels, accuracy_scores, color=['blue', 'orange', 'green'])
plt.title('Accuracy Scores')
plt.ylabel('Accuracy')
for i in range(len(labels)):
    plt.text(i, accuracy_scores[i] + 0.01, f'{accuracy_scores[i]*100:.2f}%', ha='center')
plt.tight_layout()

# Show plots and print scores
plt.show()

print(f"{'='*10} Evaluation Results {'='*10}")
for label, loss, acc in zip(labels, loss_scores, accuracy_scores):
    print(f"{label} Loss: {loss:.4f} | {label} Accuracy: {acc*100:.2f}%")
# Out:
# 138/138 [==============================] - 28s 204ms/step - loss: 0.3599 - accuracy: 0.9872
# 17/17 [==============================] - 3s 169ms/step - loss: 0.4815 - accuracy: 0.9338
# 17/17 [==============================] - 2s 118ms/step - loss: 0.6433 - accuracy: 0.8971
# ========== Evaluation Results ==========
# Train Loss: 0.3599 | Train Accuracy: 98.72%
# Validation Loss: 0.4815 | Validation Accuracy: 93.38%
# Test Loss: 0.6433 | Test Accuracy: 89.71%

# %% [markdown]
# # **Get Predictions**

# %%
preds = model.predict(test_gen)  
y_pred = np.argmax(preds, axis=1)
# Out:
# 17/17 [==============================] - 2s 125ms/step

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)
cm

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')
    
    
plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()
